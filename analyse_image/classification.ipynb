# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')

#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

#Preparation des données de tests
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])

plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])

#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")

from keras.layers import BatchNormalization

reseauNeurones4Convolution = Sequential()

reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=dimentionImage))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Flatten())
reseauNeurones4Convolution.add(Dense(512, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(128, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(10, activation='softmax'))

reseauNeurones4Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurones4Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))

evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])

historique_apprentissage = reseauNeurones4Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8113 - loss: 0.5385 - val_accuracy: 0.8711 - val_loss: 0.3857
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8751 - loss: 0.3556 - val_accuracy: 0.8801 - val_loss: 0.3454
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8900 - loss: 0.3141 - val_accuracy: 0.8864 - val_loss: 0.3211
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8987 - loss: 0.2873 - val_accuracy: 0.8943 - val_loss: 0.3026
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9044 - loss: 0.2683 - val_accuracy: 0.8897 - val_loss: 0.3011
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9095 - loss: 0.2547 - val_accuracy: 0.9028 - val_loss: 0.2737
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.9145 - loss: 0.2381 - val_accuracy: 0.9049 - val_loss: 0.2676
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.9185 - loss: 0.2253 - val_accuracy: 0.9062 - val_loss: 0.2634
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.9229 - loss: 0.2133 - val_accuracy: 0.9083 - val_loss: 0.2564
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9273 - loss: 0.2029 - val_accuracy: 0.9069 - val_loss: 0.2587
# Erreur: 0.24018703401088715
# Précision: 0.9150000214576721
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8248 - loss: 0.4679 - val_accuracy: 0.8452 - val_loss: 0.4112
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8633 - loss: 0.3817
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8633 - loss: 0.3817 - val_accuracy: 0.8494 - val_loss: 0.4100
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8479 - loss: 0.4077 - val_accuracy: 0.8549 - val_loss: 0.3970
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.3753 - val_accuracy: 0.8511 - val_loss: 0.4070
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.8553 - loss: 0.3902 - val_accuracy: 0.8608 - val_loss: 0.3810
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3334 - val_accuracy: 0.8596 - val_loss: 0.3809
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8606 - loss: 0.3756 - val_accuracy: 0.8649 - val_loss: 0.3679
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8477 - loss: 0.3860 - val_accuracy: 0.8610 - val_loss: 0.3715
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8648 - loss: 0.3642 - val_accuracy: 0.8629 - val_loss: 0.3680
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8516 - loss: 0.3352 - val_accuracy: 0.8663 - val_loss: 0.3559
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8689 - loss: 0.3582 - val_accuracy: 0.8683 - val_loss: 0.3537
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.4385 - val_accuracy: 0.8717 - val_loss: 0.3541
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8699 - loss: 0.3496 - val_accuracy: 0.8775 - val_loss: 0.3360
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2742 - val_accuracy: 0.8726 - val_loss: 0.3367
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8749 - loss: 0.3401 - val_accuracy: 0.8710 - val_loss: 0.3467
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3226 - val_accuracy: 0.8731 - val_loss: 0.3387
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8760 - loss: 0.3365 - val_accuracy: 0.8778 - val_loss: 0.3287
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3124 - val_accuracy: 0.8783 - val_loss: 0.3337
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8778 - loss: 0.3259 - val_accuracy: 0.8768 - val_loss: 0.3299
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8672 - loss: 0.3642 - val_accuracy: 0.8759 - val_loss: 0.3298
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8801 - loss: 0.3248 - val_accuracy: 0.8832 - val_loss: 0.3223
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.3789 - val_accuracy: 0.8813 - val_loss: 0.3182
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8806 - loss: 0.3220 - val_accuracy: 0.8714 - val_loss: 0.3350
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.3193 - val_accuracy: 0.8733 - val_loss: 0.3409
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8838 - loss: 0.3146 - val_accuracy: 0.8791 - val_loss: 0.3288
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3761 - val_accuracy: 0.8751 - val_loss: 0.3340
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8859 - loss: 0.3087 - val_accuracy: 0.8826 - val_loss: 0.3140
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8906 - loss: 0.3024 - val_accuracy: 0.8826 - val_loss: 0.3168
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8858 - loss: 0.3093 - val_accuracy: 0.8888 - val_loss: 0.3048
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8906 - loss: 0.2814 - val_accuracy: 0.8818 - val_loss: 0.3175
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8871 - loss: 0.3066 - val_accuracy: 0.8864 - val_loss: 0.3063
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9141 - loss: 0.2442 - val_accuracy: 0.8873 - val_loss: 0.3051
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8871 - loss: 0.3057 - val_accuracy: 0.8932 - val_loss: 0.2897
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8945 - loss: 0.2585 - val_accuracy: 0.8882 - val_loss: 0.3008
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8896 - loss: 0.3008 - val_accuracy: 0.8802 - val_loss: 0.3181
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2927 - val_accuracy: 0.8827 - val_loss: 0.3163
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8911 - loss: 0.2967 - val_accuracy: 0.8896 - val_loss: 0.2983
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3851 - val_accuracy: 0.8909 - val_loss: 0.2964
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8920 - loss: 0.2924 - val_accuracy: 0.8850 - val_loss: 0.3082
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2905 - val_accuracy: 0.8871 - val_loss: 0.3011
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8921 - loss: 0.2912 - val_accuracy: 0.8882 - val_loss: 0.2990
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8398 - loss: 0.3809 - val_accuracy: 0.8905 - val_loss: 0.2951
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8909 - loss: 0.2900 - val_accuracy: 0.8952 - val_loss: 0.2882
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9023 - loss: 0.3003 - val_accuracy: 0.8915 - val_loss: 0.2950
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8926 - loss: 0.2857 - val_accuracy: 0.8922 - val_loss: 0.2932
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8867 - loss: 0.2647 - val_accuracy: 0.8926 - val_loss: 0.2988
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8950 - loss: 0.2852 - val_accuracy: 0.8906 - val_loss: 0.2947
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9258 - loss: 0.2448 - val_accuracy: 0.8941 - val_loss: 0.2918
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8938 - loss: 0.2870 - val_accuracy: 0.8892 - val_loss: 0.2971
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8828 - loss: 0.2976 - val_accuracy: 0.8896 - val_loss: 0.2962
# Erreur : 0.24345454573631287
# Précision: 0.9150999784469604
# Modèle sauvegardé !
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 30s 138ms/step - accuracy: 0.7440 - loss: 0.7367 - val_accuracy: 0.2284 - val_loss: 2.5869
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 26s 135ms/step - accuracy: 0.8433 - loss: 0.4371 - val_accuracy: 0.5434 - val_loss: 1.7112
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 40s 132ms/step - accuracy: 0.8690 - loss: 0.3725 - val_accuracy: 0.8665 - val_loss: 0.3707
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 25s 133ms/step - accuracy: 0.8829 - loss: 0.3322 - val_accuracy: 0.8843 - val_loss: 0.3304
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 25s 135ms/step - accuracy: 0.8903 - loss: 0.3084 - val_accuracy: 0.9007 - val_loss: 0.2763
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.8965 - loss: 0.2883 - val_accuracy: 0.9033 - val_loss: 0.2684
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.9016 - loss: 0.2725 - val_accuracy: 0.9098 - val_loss: 0.2464
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 26s 136ms/step - accuracy: 0.9067 - loss: 0.2614 - val_accuracy: 0.9142 - val_loss: 0.2380
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.9104 - loss: 0.2501 - val_accuracy: 0.9154 - val_loss: 0.2316
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 25s 134ms/step - accuracy: 0.9145 - loss: 0.2381 - val_accuracy: 0.9189 - val_loss: 0.2275
# Erreur: 0.21623046696186066
# Précision: 0.9221000075340271
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.8509 - loss: 0.4125 - val_accuracy: 0.8657 - val_loss: 0.3569
# Epoch 2/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8516 - loss: 0.4518 - val_accuracy: 0.8657 - val_loss: 0.3571
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 143ms/step - accuracy: 0.8688 - loss: 0.3615 - val_accuracy: 0.8763 - val_loss: 0.3375
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8789 - loss: 0.3422 - val_accuracy: 0.8754 - val_loss: 0.3364
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.8761 - loss: 0.3421 - val_accuracy: 0.8881 - val_loss: 0.3070
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8945 - loss: 0.3421 - val_accuracy: 0.8888 - val_loss: 0.3045
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 141ms/step - accuracy: 0.8816 - loss: 0.3336 - val_accuracy: 0.8907 - val_loss: 0.3019
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8750 - loss: 0.3430 - val_accuracy: 0.8898 - val_loss: 0.3023
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 39s 143ms/step - accuracy: 0.8795 - loss: 0.3291 - val_accuracy: 0.8795 - val_loss: 0.3311
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9062 - loss: 0.2695 - val_accuracy: 0.8847 - val_loss: 0.3203
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 143ms/step - accuracy: 0.8859 - loss: 0.3142 - val_accuracy: 0.8971 - val_loss: 0.2771
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8906 - loss: 0.3934 - val_accuracy: 0.9004 - val_loss: 0.2780
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 145ms/step - accuracy: 0.8883 - loss: 0.3110 - val_accuracy: 0.8975 - val_loss: 0.2824
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8789 - loss: 0.3205 - val_accuracy: 0.8987 - val_loss: 0.2773
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 145ms/step - accuracy: 0.8912 - loss: 0.2993 - val_accuracy: 0.9009 - val_loss: 0.2749
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8789 - loss: 0.3486 - val_accuracy: 0.9008 - val_loss: 0.2724
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - accuracy: 0.8929 - loss: 0.2945 - val_accuracy: 0.8976 - val_loss: 0.2734
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8984 - loss: 0.2854 - val_accuracy: 0.8942 - val_loss: 0.2794
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 142ms/step - accuracy: 0.8949 - loss: 0.2889 - val_accuracy: 0.8993 - val_loss: 0.2818
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8789 - loss: 0.3549 - val_accuracy: 0.8986 - val_loss: 0.2900
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 144ms/step - accuracy: 0.8968 - loss: 0.2876 - val_accuracy: 0.9058 - val_loss: 0.2601
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8867 - loss: 0.3190 - val_accuracy: 0.9046 - val_loss: 0.2585
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.8968 - loss: 0.2831 - val_accuracy: 0.9033 - val_loss: 0.2568
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8867 - loss: 0.2529 - val_accuracy: 0.9015 - val_loss: 0.2547
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.8967 - loss: 0.2851 - val_accuracy: 0.8980 - val_loss: 0.2714
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8750 - loss: 0.2864 - val_accuracy: 0.8915 - val_loss: 0.2863
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 141ms/step - accuracy: 0.9007 - loss: 0.2764 - val_accuracy: 0.9079 - val_loss: 0.2570
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8984 - loss: 0.2356 - val_accuracy: 0.9093 - val_loss: 0.2562
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 144ms/step - accuracy: 0.9006 - loss: 0.2728 - val_accuracy: 0.9050 - val_loss: 0.2557
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9258 - loss: 0.2934 - val_accuracy: 0.9054 - val_loss: 0.2530
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9032 - loss: 0.2677 - val_accuracy: 0.9001 - val_loss: 0.2680
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9023 - loss: 0.3129 - val_accuracy: 0.9060 - val_loss: 0.2550
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 26s 141ms/step - accuracy: 0.9036 - loss: 0.2704 - val_accuracy: 0.9116 - val_loss: 0.2404
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9023 - loss: 0.2853 - val_accuracy: 0.9102 - val_loss: 0.2376
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 145ms/step - accuracy: 0.9034 - loss: 0.2657 - val_accuracy: 0.9149 - val_loss: 0.2272
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9102 - loss: 0.2554 - val_accuracy: 0.9140 - val_loss: 0.2365
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 144ms/step - accuracy: 0.9038 - loss: 0.2632 - val_accuracy: 0.9102 - val_loss: 0.2416
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9219 - loss: 0.2340 - val_accuracy: 0.9092 - val_loss: 0.2460
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 144ms/step - accuracy: 0.9067 - loss: 0.2568 - val_accuracy: 0.9109 - val_loss: 0.2417
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8906 - loss: 0.2627 - val_accuracy: 0.9138 - val_loss: 0.2373
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.9059 - loss: 0.2602 - val_accuracy: 0.9102 - val_loss: 0.2479
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9102 - loss: 0.2127 - val_accuracy: 0.9086 - val_loss: 0.2515
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 142ms/step - accuracy: 0.9086 - loss: 0.2572 - val_accuracy: 0.9114 - val_loss: 0.2439
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9180 - loss: 0.2296 - val_accuracy: 0.9123 - val_loss: 0.2405
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 144ms/step - accuracy: 0.9072 - loss: 0.2533 - val_accuracy: 0.9089 - val_loss: 0.2407
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9180 - loss: 0.2515 - val_accuracy: 0.9134 - val_loss: 0.2314
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 146ms/step - accuracy: 0.9090 - loss: 0.2533 - val_accuracy: 0.9155 - val_loss: 0.2350
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9414 - loss: 0.1816 - val_accuracy: 0.9131 - val_loss: 0.2356
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 27s 145ms/step - accuracy: 0.9096 - loss: 0.2480 - val_accuracy: 0.9119 - val_loss: 0.2447
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9023 - loss: 0.2487 - val_accuracy: 0.9153 - val_loss: 0.2358
# Erreur : 0.20789697766304016
# Précision: 0.9222999811172485
